# %%
import numpy as np
import pandas as pd

# %%
a1
# Out:
# array([[7, 4, 7, 4],
#        [5, 6, 3, 3],
#        [3, 5, 5, 8]])

# %%
df = pd.DataFrame(a1, columns = ['Ajay', 'Vijay', 'Rajay', 'Lajay'], index = ['a','b','c'])

# %%
df1 = pd.read_csv('/Users/shubhamdubey/Desktop/Chapter Push/U&D Quest.csv', index_col= False)
df1
# Out:
#      Requested Category ID Requested Category Type        Grade Syllabus  \
# 0                   187671         ChapterCategory  Standard XI     NEET
# 1                   187671         ChapterCategory  Standard XI     NEET
# 2                   187671         ChapterCategory  Standard XI     NEET
# 3                   187671         ChapterCategory  Standard XI     NEET
# 4                   187671         ChapterCategory  Standard XI     NEET
# ..                     ...                     ...          ...      ...
# 687                 187671         ChapterCategory  Standard XI     NEET
# 688                 187671         ChapterCategory  Standard XI     NEET
# 689                 187671         ChapterCategory  Standard XI     NEET
# 690                 187671         ChapterCategory  Standard XI     NEET
# 691                 187671         ChapterCategory  Standard XI     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
df1.shape
# Out:
# (692, 54)

# %%
df1.columns
# Out:
# Index(['Requested Category ID', 'Requested Category Type', 'Grade', 'Syllabus',
#        'Root Category Id', 'Subject', 'Chapter Id', 'Chapter Name',
#        'Chapter Included In Tnl Json', 'Subtopic Id', 'Subtopic Name',
#        'Subtopic Included In Tnl Json', 'Question Id', 'Question Name',
#        'Question Title', 'Type', 'Is Published', 'Is Practice', 'Is Deleted',
#        'Is Quizup Eligible', 'Is Archived', 'Assessment Usages',
#        'Assessment Types', 'AdaptiveUsage', 'Question Flow(LJ)_',
#        'Learn Usages', 'Solution Video - ID', 'Hint Type', 'Hint Text',
#        'Difficulty', 'Skill', 'Primary Concepts', 'Primary Concepts IDS',
#        'Primary Concept Subtopic', 'Secondary Concepts',
#        'Secondary Concepts IDS', 'Raw Question ID', 'Owner',
#        'Raw Question created at', 'Raw Question Updated at',
#        'Last Approval Request', 'Approval Status', 'Approver',
#        'Approval Time/Last Edited', 'Solution Present', 'Solution Length',
# ...

# %%
df1
# Out:
#              Requested Category ID Requested Category Type Syllabus  \
# Grade
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# ...                            ...                     ...      ...
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
#
#              Root Category Id  Subject  Chapter Id          Chapter Name  \
# Grade
# ...

# %%
df1.values
# Out:
# array([[187671, 'ChapterCategory', 'NEET', ..., -1.0, nan, nan],
#        [187671, 'ChapterCategory', 'NEET', ..., -1.0, nan, nan],
#        [187671, 'ChapterCategory', 'NEET', ..., -1.0, nan, nan],
#        ...,
#        [187671, 'ChapterCategory', 'NEET', ..., -1.0, nan, nan],
#        [187671, 'ChapterCategory', 'NEET', ..., -1.0, nan, nan],
#        [187671, 'ChapterCategory', 'NEET', ..., 0.0, nan, nan]],
#       dtype=object)

# %%
df1
# Out:
#              Requested Category ID Requested Category Type Syllabus  \
# Grade
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# ...                            ...                     ...      ...
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
#
#              Root Category Id  Subject  Chapter Id          Chapter Name  \
# Grade
# ...

# %%
df1.axes
# Out:
# [Index(['Standard XI', 'Standard XI', 'Standard XI', 'Standard XI',
#         'Standard XI', 'Standard XI', 'Standard XI', 'Standard XI',
#         'Standard XI', 'Standard XI',
#         ...
#         'Standard XI', 'Standard XI', 'Standard XI', 'Standard XI',
#         'Standard XI', 'Standard XI', 'Standard XI', 'Standard XI',
#         'Standard XI', 'Standard XI'],
#        dtype='object', name='Grade', length=692),
#  Index(['Requested Category ID', 'Requested Category Type', 'Syllabus',
#         'Root Category Id', 'Subject', 'Chapter Id', 'Chapter Name',
#         'Chapter Included In Tnl Json', 'Subtopic Id', 'Subtopic Name',
#         'Subtopic Included In Tnl Json', 'Question Id', 'Question Name',
#         'Question Title', 'Type', 'Is Published', 'Is Practice', 'Is Deleted',
#         'Is Quizup Eligible', 'Is Archived', 'Assessment Usages',
#         'Assessment Types', 'AdaptiveUsage', 'Question Flow(LJ)_',
# ...

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#            Grade  Requested Category ID Requested Category Type Syllabus  \
# 0    Standard XI                 187671         ChapterCategory     NEET
# 1    Standard XI                 187671         ChapterCategory     NEET
# 2    Standard XI                 187671         ChapterCategory     NEET
# 3    Standard XI                 187671         ChapterCategory     NEET
# 4    Standard XI                 187671         ChapterCategory     NEET
# ..           ...                    ...                     ...      ...
# 687  Standard XI                 187671         ChapterCategory     NEET
# 688  Standard XI                 187671         ChapterCategory     NEET
# 689  Standard XI                 187671         ChapterCategory     NEET
# 690  Standard XI                 187671         ChapterCategory     NEET
# 691  Standard XI                 187671         ChapterCategory     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
df1.set_index('Grade')
# Out:
#              Requested Category ID Requested Category Type Syllabus  \
# Grade
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# ...                            ...                     ...      ...
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
# Standard XI                 187671         ChapterCategory     NEET
#
#              Root Category Id  Subject  Chapter Id          Chapter Name  \
# Grade
# ...

# %%
df1.reset_index(inplace = True)
df1
# Out:
#      level_0  index        Grade  Requested Category ID  \
# 0          0      0  Standard XI                 187671
# 1          1      1  Standard XI                 187671
# 2          2      2  Standard XI                 187671
# 3          3      3  Standard XI                 187671
# 4          4      4  Standard XI                 187671
# ..       ...    ...          ...                    ...
# 687      687    687  Standard XI                 187671
# 688      688    688  Standard XI                 187671
# 689      689    689  Standard XI                 187671
# 690      690    690  Standard XI                 187671
# 691      691    691  Standard XI                 187671
#
#     Requested Category Type Syllabus  Root Category Id  Subject  Chapter Id  \
# 0           ChapterCategory     NEET            123747  Physics      187671
# 1           ChapterCategory     NEET            123747  Physics      187671
# ...

# %%
df1.drop(['level_0','index' ])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/1t/y1s57kbs09n36v7x7r4rml400000gn/T/ipykernel_10879/230551369.py in <module>
# ----> 1 df1.drop(['level_0','index' ])
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df1.drop(['level_0', 'index'], inplace = True, axis =1 )

# %%
df1
# Out:
#            Grade  Requested Category ID Requested Category Type Syllabus  \
# 0    Standard XI                 187671         ChapterCategory     NEET
# 1    Standard XI                 187671         ChapterCategory     NEET
# 2    Standard XI                 187671         ChapterCategory     NEET
# 3    Standard XI                 187671         ChapterCategory     NEET
# 4    Standard XI                 187671         ChapterCategory     NEET
# ..           ...                    ...                     ...      ...
# 687  Standard XI                 187671         ChapterCategory     NEET
# 688  Standard XI                 187671         ChapterCategory     NEET
# 689  Standard XI                 187671         ChapterCategory     NEET
# 690  Standard XI                 187671         ChapterCategory     NEET
# 691  Standard XI                 187671         ChapterCategory     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
df1
# Out:
#            Grade  Requested Category ID Requested Category Type Syllabus  \
# 0    Standard XI                 187671         ChapterCategory     NEET
# 1    Standard XI                 187671         ChapterCategory     NEET
# 2    Standard XI                 187671         ChapterCategory     NEET
# 3    Standard XI                 187671         ChapterCategory     NEET
# 4    Standard XI                 187671         ChapterCategory     NEET
# ..           ...                    ...                     ...      ...
# 687  Standard XI                 187671         ChapterCategory     NEET
# 688  Standard XI                 187671         ChapterCategory     NEET
# 689  Standard XI                 187671         ChapterCategory     NEET
# 690  Standard XI                 187671         ChapterCategory     NEET
# 691  Standard XI                 187671         ChapterCategory     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
df1.value_counts
# Out:
# <bound method DataFrame.value_counts of      Requested Category ID Requested Category Type        Grade Syllabus  \
# 0                   187671         ChapterCategory  Standard XI     NEET
# 1                   187671         ChapterCategory  Standard XI     NEET
# 2                   187671         ChapterCategory  Standard XI     NEET
# 3                   187671         ChapterCategory  Standard XI     NEET
# 4                   187671         ChapterCategory  Standard XI     NEET
# ..                     ...                     ...          ...      ...
# 687                 187671         ChapterCategory  Standard XI     NEET
# 688                 187671         ChapterCategory  Standard XI     NEET
# 689                 187671         ChapterCategory  Standard XI     NEET
# 690                 187671         ChapterCategory  Standard XI     NEET
# 691                 187671         ChapterCategory  Standard XI     NEET
#
# ...

# %%
df
# Out:
#    Ajay  Vijay  Rajay  Lajay
# a     7      4      7      4
# b     5      6      3      3
# c     3      5      5      8

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of    Ajay  Vijay  Rajay  Lajay
# a     7      4      7      4
# b     5      6      3      3
# c     3      5      5      8>

# %%
df1['Grade'].value_counts()
# Out:
# Standard XI    692
# Name: Grade, dtype: int64

# %%
df1
# Out:
#      Requested Category ID Requested Category Type        Grade Syllabus  \
# 0                   187671         ChapterCategory  Standard XI     NEET
# 1                   187671         ChapterCategory  Standard XI     NEET
# 2                   187671         ChapterCategory  Standard XI     NEET
# 3                   187671         ChapterCategory  Standard XI     NEET
# 4                   187671         ChapterCategory  Standard XI     NEET
# ..                     ...                     ...          ...      ...
# 687                 187671         ChapterCategory  Standard XI     NEET
# 688                 187671         ChapterCategory  Standard XI     NEET
# 689                 187671         ChapterCategory  Standard XI     NEET
# 690                 187671         ChapterCategory  Standard XI     NEET
# 691                 187671         ChapterCategory  Standard XI     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
df1.iloc[5:10, 6:9]
# Out:
#    Chapter Id          Chapter Name  Chapter Included In Tnl Json
# 5      187671  Units and Dimensions                          True
# 6      187671  Units and Dimensions                          True
# 7      187671  Units and Dimensions                          True
# 8      187671  Units and Dimensions                          True
# 9      187671  Units and Dimensions                          True

# %%
df1.sort_values(['Root Category Id', 'Subtopic Id'])
# Out:
#      Requested Category ID Requested Category Type        Grade Syllabus  \
# 7                   187671         ChapterCategory  Standard XI     NEET
# 9                   187671         ChapterCategory  Standard XI     NEET
# 11                  187671         ChapterCategory  Standard XI     NEET
# 13                  187671         ChapterCategory  Standard XI     NEET
# 14                  187671         ChapterCategory  Standard XI     NEET
# ..                     ...                     ...          ...      ...
# 185                 187671         ChapterCategory  Standard XI     NEET
# 186                 187671         ChapterCategory  Standard XI     NEET
# 187                 187671         ChapterCategory  Standard XI     NEET
# 188                 187671         ChapterCategory  Standard XI     NEET
# 189                 187671         ChapterCategory  Standard XI     NEET
#
#      Root Category Id  Subject  Chapter Id          Chapter Name  \
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.loads('Iris')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/1t/y1s57kbs09n36v7x7r4rml400000gn/T/ipykernel_10879/3322010817.py in <module>
# ----> 1 sns.loads('Iris')
#
# AttributeError: module 'seaborn' has no attribute 'loads'

# %%
df = sns.load_dataset('iris')

# %%
df.plot( x = 'sepal_length', y =  'sepal_width', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.heatmap(df[['sepal_length', 'sepal_width'']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/1t/y1s57kbs09n36v7x7r4rml400000gn/T/ipykernel_10879/4078436084.py in <module>
# ----> 1 sns.heatmap(df)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     538     """
#     539     # Initialize the plotter object
# --> 540     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...
